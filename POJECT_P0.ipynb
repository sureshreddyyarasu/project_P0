# %%
import os
import pymysql
import pandas as pd

host = os.getenv('MYSQL_HOST')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
database = os.getenv('MYSQL_DATABASE')

con = pymysql.connect(
    host=host,
    port=int(3306),
    user="root",
    passwd="root",
    db="l1"
    )
def addbook():
    bname=input("ENTER BOOK NAME :")
    bcode=input("ENTER BOOK CODE : ")
    total=input("TOTAL BOOKS : ")
    subject=input("Enter SUBJECT: ")
    data=(bname,bcode,total,subject)
    sql='insert into books values(%s,%s,%s,%s)'
    c=con.cursor()
    c.execute(sql,data)
    con.commit()
    print("*******************")
    print("Data Entered Sucessfully")
    main()
def issueb():
    name=input("Enter Name: ")
    regno=input("Enter Reg No: ")
    bcode=input("Enter BOOK CODE : ")
    issue=input("Enter Date :")
    a='insert into issue values(%s,%s,%s,%s)' 
    data=(name,regno,bcode,issue)
    c=con.cursor()
    c.execute(a,data)
    con.commit()
    print("*********************")
    print("Book issued to :",name)
    bookup(bcode,-1)
def bookup(bcode,u):
    a="select total from books where bcode=%s"
    data=(bcode,)
    c=con.cursor()
    c.execute(a,data)
    myresult=c.fetchone()
    t=myresult[0]+u
    sql="update books set total =%s Where bcode=%s"
    d=(t,bcode)
    c.execute(sql,d)
    con.commit()
    main()
def submitb():
    name=input("Enter Name: ")
    regno=input("Enter Reg No: ")
    bcode=input("Enter BOOK CODE : ")
    submit=input("Enter Date :")
    a='insert into submit values(%s,%s,%s,%s)' 
    data=(name,regno,bcode,submit)
    c=con.cursor()
    c.execute(a,data)
    con.commit()
    print("*********************")
    print("Book submitted :",name)
    bookup(bcode,1)
def delbook():
    bcode=input("Enter Book Code :")
    a='delete from books where bcode=%s'
    data=(bcode,)
    c=con.cursor()
    c.execute(a,data)
    con.commit()
    main()
def display():
    a='select*from books'
    c=con.cursor()
    c.execute(a)
    myresult=c.fetchall()
    for i in myresult:
        print("BOOK NAME :",i[0])
        print("BOOK CODE :",i[1])
        print("TOTAL BOOKS",i[2])
        print("--------------------------------------------------------------------------")
    main()  

def main():
    print("********** WELCOME TO ROOM LIBRARY *************")
    print("1.Display books") 
    print ("2.ADD BOOK")
    print("3.ISSUE BOOK") 
    print("4.submit BOOK")
    print("5.delete Book ")
    print("0.EXIST")
    c=input("ENTER YOUR CHOICE:  ")
    if (c=='1'):
        display()
    elif (c=='2'):
        addbook()
    elif(c=='3'):
        issueb()
    elif(c=='4'):
        submitb()
    elif (c=='5'):
        delbook()
    elif(c=='0'):
        print(" THANK YOU")
        pass
        
    else:
        print("SELECT VAILD OPTIONS")
        main()
def pswd():
    ps=input("ENTER THE PASSWORD : ")
    if ps=="SURESH":
        main()
    else:
        print("wrong password RE ENTER THE PROJECT")
        pswd()
    
pswd()
# Out:
# ENTER THE PASSWORD : SURESH
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
# ENTER YOUR CHOICE:  1
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
# ENTER YOUR CHOICE:  1
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
# ENTER YOUR CHOICE:  1
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
# ENTER YOUR CHOICE:  2
# ENTER BOOK NAME :ENGLISH
# ENTER BOOK CODE : 234
# TOTAL BOOKS : 34
# Enter SUBJECT: SDFGHJK
# *******************
# Data Entered Sucessfully
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
# ENTER YOUR CHOICE:  1
# BOOK NAME : ENGLISH
# BOOK CODE : 234
# TOTAL BOOKS 34
# --------------------------------------------------------------------------
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
# ENTER YOUR CHOICE:  3
# Enter Name: ENGLISH
# Enter Reg No: 2345
# Enter BOOK CODE : 234
# Enter Date :12-04-2000
# *********************
# Book issued to : ENGLISH
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
# ENTER YOUR CHOICE:  4
# Enter Name: HINDI
# Enter Reg No: 234
# Enter BOOK CODE : 234
# Enter Date :4-456-456
# *********************
# Book submitted : HINDI
# ********** WEKCOME TO BOOM LIBRARY *************
# 1.Display books
# 2.ADD BOOK
# 3.ISSUE BOOK
# 4.submit BOOK
# 5.delete Book
# 0.EXIST
